# %%
from IPython.core.display import HTML
from bs4 import BeautifulSoup, UnicodeDammit
import pandas as pd
import StringIO
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

# %%
import requests
z = requests.get('http://espn.go.com/nba/standings')

# %%
print z.text
# Out:
# <!DOCTYPE html>
# 	<!--[if !IE]><!--><html class="no-icon-fonts"><!--<![endif]-->
# 	<!--[if IE 9]><html class="ie9 no-icon-fonts"><![endif]-->
# 	<!--[if lt IE 9]><html class="ie8"><![endif]-->
# 	<head>
# 		<meta http-equiv="x-ua-compatible" content="IE=edge,chrome=1" />
# <meta http-equiv="content-type" content="text/html; charset=iso-8859-1" />
# <meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
# <link rel="canonical" href="http://espn.go.com/nba/standings" />
# <title>NBA Regular Season Conference Standings - National Basketball Association</title>
# <meta name="description" content="Check out the 2015-16 NBA Regular Season Conference Standings." />
# <meta name="news_keywords" content="" />
# <meta name="keywords" content="" />
# <meta property="fb:app_id" content="116656161708917" />
# <meta property="og:site_name" content="ESPN.com" />
# <meta property="og:url" content="http://espn.go.com/nba/standings" />
# <meta property="og:title" content="NBA Regular Season Conference Standings - National Basketball Association"/>
# <meta property="og:description" content="Check out the 2015-16 NBA Regular Season Conference Standings." />
# <meta property="og:image" content="http://a1.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fespn_logos%2Fespn_red.png"/>
# <meta property="og:type" content="website" />
# <meta name="twitter:site" content="espn" />
# <meta name="twitter:url" content="http://espn.go.com/nba/standings" />
# <meta name="twitter:title" content="NBA Regular Season Conference Standings - National Basketball Association"/>
# <meta name="twitter:description" content="Check out the 2015-16 NBA Regular Season Conference Standings." />
# <meta name="twitter:image" content="http://a1.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fespn_logos%2Fespn_red.png"/>
# <meta name="twitter:card" content="summary">
# <meta name="twitter:app:name:iphone" content="ESPN"/>
# <meta name="twitter:app:id:iphone" content="317469184"/>
# <meta name="twitter:app:name:googleplay" content="ESPN"/>
# <meta name="twitter:app:id:googleplay" content="com.espn.score_center"/>
# <meta name="title" content="NBA Regular Season Conference Standings - National Basketball Association"/>
# <meta name="medium" content="website" />
#
# <!-- Indicate preferred brand name for Google to display -->
# <script type="application/ld+json">
# 	{
# 		"@context": "http://schema.org",
# 		"@type":    "WebSite",
# 		"name":     "ESPN",
# 		"url":      "http://espn.go.com/"
# 	}
# </script>
# <!--
# <PageMap>
# 	<DataObject type="document">
# 		<Attribute name="title">NBA Regular Season Conference Standings - National Basketball Association</Attribute>
# 	</DataObject>
# </PageMap>
# -->
#
# <link href='http://a.espncdn.com' rel='preconnect' crossorigin>
# <link href='http://a1.espncdn.com' rel='preconnect' crossorigin>
# <link href='http://a2.espncdn.com' rel='preconnect' crossorigin>
# <link href='http://a3.espncdn.com' rel='preconnect' crossorigin>
# <link href='http://a4.espncdn.com' rel='preconnect' crossorigin>
# <link href='http://tredir.go.com' rel='preconnect' crossorigin>
# <link href='https://cdn.registerdisney.go.com' rel='preconnect' crossorigin>
# <link href='http://fan.api.espn.go.com' rel='preconnect' crossorigin>
# <link href='http://cdn.espn.go.com' rel='preconnect' crossorigin>
#
# <link rel="mask-icon" sizes="any" href="http://a.espncdn.com/prod/assets/icons/E.svg" color="#990000">
# <link rel="shortcut icon" href="http://a.espncdn.com/favicon.ico" />
# <link rel="apple-touch-icon" href="http://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons/espn_icon-57x57.min.png" />
# <link rel="apple-touch-icon-precomposed" href="http://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons/espn_icon-57x57.min.png">
# <link rel="apple-touch-icon-precomposed" sizes="72x72" href="http://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons/espn_icon-72x72.min.png">
# <link rel="apple-touch-icon-precomposed" sizes="114x114" href="http://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons/espn_icon-114x114.min.png">
# <link rel="apple-touch-icon-precomposed" sizes="152x152" href="http://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons/espn_icon-152x152.min.png">
# <link rel="alternate" href="android-app://com.espn.score_center/sportscenter/x-callback-url/showClubhouse?uid=s:40~l:46&section=standings" />
# <link rel="alternate" href="ios-app://317469184/sportscenter/x-callback-url/showClubhouse?uid=s:40~l:46&section=standings" />
# <link id="font-link" rel="stylesheet" href="http://a.espncdn.com/redesign/fonts/base64-benton-woff.css">
# 	<script>!function(e){"use strict";e.loadCSS=function(t,n,r){var i,l=e.document,o=l.createElement("link");if(n)i=n;else{var a=(l.body||l.getElementsByTagName("head")[0]).childNodes;i=a[a.length-1]}var s=l.styleSheets;o.rel="stylesheet",o.href=t,o.media="only x",i.parentNode.insertBefore(o,n?i:i.nextSibling);var f=function(e){for(var t=o.href,n=s.length;n--;)if(s[n].href===t)return e();setTimeout(function(){f(e)})};return o.onloadcssdefined=f,f(function(){o.media=r||"all"}),o}}(this);function onloadCSS(n,o){n.onload=function(){n.onload=null,o&&o.call(n)},"isApplicationInstalled"in navigator&&"onloadcssdefined"in n&&n.onloadcssdefined(o)}</script>
# 	<script>
# 	(function() {
# 	    var ttf = (navigator.userAgent.match(/Android (4|3|2)./) && navigator.userAgent.indexOf("like Gecko") > -1 && navigator.userAgent.indexOf("Chrome") === -1),
# 	        stylesheet = loadCSS("http://a.espncdn.com/redesign/fonts/base64-icons-" + ((ttf) ? "ttf" : "woff-v5") + ".css");
# 	    onloadCSS(stylesheet, function() {
# 	        document.documentElement.className = document.documentElement.className.replace("no-icon-fonts", "")
# 	    });
# 	})();
# 	</script>
# 	<noscript><link href="http://a.espncdn.com/redesign/fonts/base64-icons-woff-v5.css" rel="stylesheet"></noscript>
#
# <!--[if IE 9]>
# <script>window.isIE9 = true;</script>
# <link rel="stylesheet" href="http://a.espncdn.com/redesign/0.283.6/css/page-ie9.css"><link class="page-type-include" rel="stylesheet" href="http://a.espncdn.com/redesign/0.283.6/css/standings-ie9.css">
# <style>
# #main-container {
# 	visibility:visible !important;
# }
# </style>
# <![endif]-->
# <!--[if !IE]><!-->
# <link rel="stylesheet" href="http://a.espncdn.com/redesign/0.283.6/css/page.css"><link class="page-type-include" rel="stylesheet" href="http://a.espncdn.com/redesign/0.283.6/css/standings.css"><!--<![endif]-->
# 		<script type="text/javascript">
#
# 			// load new edition settings
# 			var espn = espn || {};
# 			espn.i18n = espn.i18n || {};
# 			espn.i18n.lang = "en";
# 			espn.i18n.siteId = "1";
# 			espn.i18n.site = "espn";
# 			espn.i18n.editionKey = "espn-en";
# 			espn.i18n.personalization = true;
# 			espn.i18n.country = "us";
# 			espn.i18n.domain = "espn.go.com";
# 			espn.i18n.searchUrl = "http://search.espn.go.com/",
# 			espn.i18n.temperature = {scale: "fahrenheit", symbol: "&deg; F" };
# 			espn.i18n.facebook = {appId: "116656161708917", locale: "en_US" };
# 			espn.i18n.outbrain = {mobile: {compliantId: "MB_4", nonCompliantId: "MB_5"},
# 									desktop: {compliantId: "AR_15", nonCompliantId: "AR_12"} };
# 			espn.i18n.betting = {show: true, provider: ""};
# 			espn.i18n.ticketsEnabled = true;
# 			espn.i18n.translations = {};
# 			espn.i18n.environment = "local";
# 			espn.i18n.sportBranding = {"cricket":"logo-uk-cricinfo.png","soccer":"logo-uk-fc.png","soccer":"logo-uk-scrum.png","ncaaw":"ESPNcom-powerby-espnw.png"};
# 			espn.i18n.sportToUrl = {"cricket":"http://espncricinfo.com","soccer":"http://www.espnfc.com","ncaaw":"http://espnw.com"};
# 			espn.i18n.showWatch = true;
# 			espn.i18n.indexAutoStart = false;
#
#
# 			espn.i18n.uriRewrites = {"paramKeys":{"toEdition":{},"toEnglish":{}},"pathSegments":{"toEdition":{},"toEnglish":{}},"roots":{"toEdition":{"/endurance/":"/sports/endurance/","/horse/":"/horse-racing/","/los-angeles/":"/losangeles/","/nascar/":"/racing/nascar/","/ncaa/":"/college-sports/","/ncb/":"/mens-college-basketball/","/ncf/":"/college-football/","/ncw/":"/womens-college-basketball/","/new-york/":"/newyork/","/oly/":"/figure-skating/","/onenacion/":"/espn/onenacion/","/rpm/":"/racing/","/womenbb/":"/sports/womenbb/"},"toEnglish":{"/college-football/":"/ncf/","/college-sports/":"/ncaa/","/cycling/":"/oly/","/espn/onenacion/":"/onenacion/","/figure-skating/":"/oly/","/gymnastics/":"/oly/","/horse-racing/":"/horse/","/losangeles/":"/los-angeles/","/mens-college-basketball/":"/ncb/","/newyork/":"/new-york/","/olympics/":"/oly/","/racing/":"/rpm/","/racing/nascar/":"/nascar/","/skiing/":"/oly/","/sports/endurance/":"/endurance/","/sports/horse/":"/horse/","/sports/womenbb/":"/womenbb/","/womens-basketball/":"/womenbb/","/womens-college-basketball/":"/ncw/"}},"urls":{"toEdition":{},"toEnglish":{}},"paramValues":{"toEdition":{},"toEnglish":{}}};
#
# 			try {
# 				//find way to double encode
# 				var translations = {"viewAllResultsBySearchTerm":"View all results for '${search_term}'","removedFromYourFavorites":"<p>You've removed<\/p><h1>${title}<\/h1>${subTitle}<p>as a suggested favorite<\/p>","favoritesmgmt.suggestedHeaderReset":"Suggestions","purse":"Purse","undo":"Undo","heliumdown":"Login Temporarily Unavailable","manageFavoritesSignIn":"To manage favorites please sign-in or create an ESPN account","no":"No","pageTitle.Scores_%{leagueOrSport}":"%{leagueOrSport} Scores","sports":"Sports","score":"Score","show":"Show","cancel":"Cancel","resize":"Resize","favoritesmgmt.manualSortSelected":"You have chosen to manually order how your favorites will appear across ESPN products. At any time, you may return to having ESPN order your favorites by selecting the \"Auto\" option.","nflBye":"Bye","close":"Close","redesignWelcomeText":"We've redesigned the site with some new and exciting features. You have been selected as part of a limited set of fans who get to experience our new site and give it feedback before it launches!","favoritesmgmt.favoriteEntity":"${entity} - Favorite","favoritesmgmt.reorderSports":"Reorder Sports","manageSettingInPersonalSettings":"You can manage this setting in the future under your <a href=\"#\">Personal Settings<\/a>","scores":"Scores","hide":"Hide","search":"Search","thingsHaveChanged":"As you may notice, things have definitely changed","welcomeToESPN":"Welcome to the new ESPN.com","favoritesmgmt.noFavorites":"You have not chosen any favorites yet","tweet":"Tweet","thereAreNoEventsByDisplayNameByDate":"There are no ${displayName} events for ${readableDate}","to_be_determined.abbrev":"TBD","favoriteadded":"Favorite Added","over/under.abbrev":"O/U","signOut":"Log Out","move":"Move","videoSettings":"Video Settings","favorites.draftingNow":"Drafting Now","noTeamsInFavorites":"No teams in your favorites yet","alert":"Alert","favoritesmgmt.confirmHideFavorite":"Hide this from my favorites?","enter":"Enter","welcometext":"Welcome","position.abbrev":"POS","favoritesmgmt.alertType":"Alert Type","favorites.streakLabel":"Current Streak:","email":"Email","createAccount":"Sign Up","viewall":"View All","pts":"Pts","favoritesmgmt.sportTeam":"${sportLabel} Team","favoritesmgmt.suggestedHeader":"Suggestions for your location","home":"Home","footerText":"ESPN Internet Ventures. <a href=\"http://disneytermsofuse.com/\" rel=\"nofollow\">Terms of Use<\/a>, <a href=\"http://disneyprivacycenter.com/\" rel=\"nofollow\">Privacy Policy<\/a>, <a href=\"https://disneyprivacycenter.com/notice-to-california-residents/\" rel=\"nofollow\">Your California Privacy Rights<\/a>, <a href=\"https://disneyprivacycenter.com/kids-privacy-policy/english/\">Children's Online Privacy Policy<\/a> and <a href=\"http://preferences-mgr.truste.com/?type=espn&affiliateId=148\">Interest-Based Ads<\/a> are applicable to you. All rights reserved.<\/span><span class=\"link-text-short\">Footer<\/span>","remove":"Remove","today":"Today","add":"Add","opponent.abbrev":"OPP","videoDockingDisabled":"Video docking disabled","connectfacebook":"Connect with Facebook","pop-out":"Pop-out","inprogress":"In Progress","facebook.conversation.account_policy":"Use a <a href=\"https://www.facebook.com/r.php\" rel=\"nofollow\">Facebook account<\/a> to add a comment, subject to Facebook's <a href=\"https://www.facebook.com/policies/\" rel=\"nofollow\">Terms of Service<\/a> and <a href=\"https://www.facebook.com/about/privacy/\" rel=\"nofollow\">Privacy Policy<\/a>. Your Facebook name, photo &amp; other personal information you make public on Facebook will appear with your comment, and may be used on ESPN's media platforms. <a href=\"http://espn.go.com/community/story/_/id/8756098/espn-facebook-comments-faq\">Learn more<\/a>.","earnings":"Earnings","connectedfacebook":"Connected to Facebook","disableVideoDockingPermanently":"Disable video docking permanently","addSomeForQuickAccess":"Add some for quick access","suggested":"Suggested","insider.pickcenter.login_messa ...
# 				if(Object.keys(translations).length > 0) {
# 					espn.i18n.translations = translations;
# 				}
# 			} catch (err) {
# 				window.console.log('Error in espn.i18n loading translations', err);
# 			}
#
# 			espn.i18n.dateTime = {
# 				dateFormats: {
# 					time1: "h:mm A",
# 					date1: "MMM D, YYYY",
# 					date2: "M/D/YYYY",
# 					date3: "MM/DD/YYYY",
# 					date4: "MMDDYYYY",
# 					date5: "MMMM Do YYYY",
# 					date6: "dddd, MMMM Do YYYY",
# 					date7: "ddd, MMM D YYYY",
# 					date8: "M/D",
# 					date9: "ddd",
# 					date10: "dddd, MMMM Do",
# 					date11: "ddd, MMMM D",
# 					date12: "MMMM D, YYYY",
# 					date13: "dddd, M/D",
# 					date14: "MMM D"
#
# 				},
# 				dayNamesShort: ["Su","Mo","Tu","We","Th","Fr","Sa"],dayNamesMedium: ["Sun","Mon","Tues","Wed","Thu","Fri","Sat"],
#
# dayNamesLong: ["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],
#
# monthNamesShort: ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],
#
# monthNamesLong: ["January","February","March","April","May","June","July","August","September","October","November","December"]
# 			};
#
# 		</script>
#
# 	<script src="http://a.espncdn.com/redesign/0.283.6/js/espn-head.js"></script>
#
# <script src="http://a.espncdn.com/redesign/0.283.6/js/lib/lazysizes.js" async></script>
#
# 	<script type="text/javascript">
# 		var googletag = googletag || {};
# 		googletag.cmd = googletag.cmd || [];
# 		(function() {
# 			var gads = document.createElement("script");
# 			gads.async = true;
# 			gads.type = "text/javascript";
# 			var useSSL = "https:" == document.location.protocol;
# 			gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
# 			var node = document.getElementsByTagName("script")[0];
# 			node.parentNode.insertBefore(gads, node);
# 		})();
# 	</script>
#
# 	<script type="text/javascript">
# 		var espn = espn || {};
# 		espn.ads = espn.ads || {};
# 		espn.ads.config = {"selector":".ad-slot","sizes":{"InContent2":{"defaultSize":[300,251],"mappings":[{"viewport":[0,0],"slot":[[300,251]]}]},"overlay":{"defaultSize":[0,0],"mappings":[{"viewport":[0,0],"slot":[[0,0]]}]},"incontent":{"defaultSize":[300,250],"mappings":[{"viewport":[1024,0],"slot":[[300,250],[300,600]]}]},"presby":{"defaultSize":[298,50],"mappings":[{"viewport":[0,0],"slot":[[298,50]]}]},"wallpaper":{"defaultSize":[1680,1050],"mappings":[{"viewport":[1280,0],"slot":[[1680,1050]]},{"viewport":[1024,0],"slot":[[1280,455]]},{"viewport":[0,0],"slot":[]}]},"midpage":{"defaultSize":[320,250],"mappings":[{"viewport":[1280,0],"slot":[[700,400]]},{"viewport":[1024,0],"slot":[[440,330]]},{"viewport":[768,0],"slot":[[320,250]]},{"viewport":[0,0],"slot":[[320,250]]}]},"incontentstrip":{"defaultSize":[298,50],"mappings":[{"viewport":[1024,0],"slot":[298,50]},{"viewport":[0,0],"slot":[]}]},"banner":{"defaultSize":[970,66],"mappings":[{"viewport":[1280,0],"slot":[[1280,100]]},{"viewport":[1024,0],"slot":[[970,66],[970,250]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[0,0],"slot":[[320,50]]}]}},"delayInPageAdSlots":true,"refreshOnBreakpointChange":true,"kvps":[{"name":"ed","value":"us"},{"name":"sp","value":"nba"},{"name":"pgtyp","value":"standings"}],"network":"6444","supportDynamicPageLoad":true,"id":12129264,"level":"espn.com/nba/standings","incontentPositions":{"defaults":{"now":4,"news":4,"favorites":-1},"index":{"nfl":{},"top":{"favorites":-1}}},"base":"espn.com","dynamicKeyValues":{"profile":{"key":"prof"}},"load":{"frontpage":{"tablet":"init","desktop":"init","mobile":"window.load"},"story":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"defaults":{"tablet":"init","desktop":"init","mobile":"window.load"},"index":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"schedule":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"standings":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"scoreboard":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"}},"disabled":"false","breakpoints":{"s":[0,767],"xl":[1280],"l":[1024,1279],"m":[768,1023]}};
# 		espn.ads.configPre = JSON.parse(JSON.stringify(espn.ads.config))
# 	</script>
#
#
# 		<!-- optimizely js -->
# 		<script type="text/javascript" src="http://cdn.optimizely.com/js/310987714.js" async></script>
#
#
# <script>
# 	// Picture element HTML shim|v it for old IE (pairs with Picturefill.js)
# 	document.createElement( "picture" );
# </script>
#
# 	</head>
#
# 	<body class="standings desktop " data-pagetype="standings" data-sport="nba">
# 		<div class="ad-slot ad-slot-overlay" data-slot-type="overlay" data-slot-kvps="pos=outofpage" data-out-of-page="true"></div><div class="ad-slot ad-slot-wallpaper" data-slot-type="wallpaper" data-exclude-bp="s,m" data-slot-kvps="pos=wallpaper" data-collapse-before-load="true"></div>
# 	<!-- abtest data object global -->
# 	<script type="text/javascript">
# 		var abtestData = {};
#
# 	</script>
#
#
# 		<!-- optimizely - initialize Optimizely object: temp hard-coded -->
# 		<script type="text/javascript">
# 			window['optimizely'] = window['optimizely'] || [];
# 		</script>
#
#
# 		<div id="fb-root"></div>
#
#
#         <div id="global-viewport" data-behavior="global_nav_condensed global_nav_full"  class =" interior secondary">
#
#
# <nav id="global-nav-mobile" data-loadtype="server">
# </nav>
#
#             <div class="menu-overlay-primary"></div>
#
#             <div id="header-wrapper" data-behavior="global_header" class="hidden-print">
#
# <section id="global-scoreboard" class="hide-fullbtn">
#     <div class="wrap">
#         <div class="scoreboard-content">
#
#             <div class="scoreboard-dropdown-wrapper scoreboard-menu">
#                 <!-- mobile dropdown -->
#                 <div class="league-nav-wrapper league-nav-mobile mobile-dropdown">
#                     <span class="mobile-arrow"></span>
#                     <select id="league-nav"></select>
#                 </div>
#
#                 <!-- desktop dropdown -->
#                 <div class="dropdown-wrapper league-nav-desktop desktop-dropdown" data-behavior="button_dropdown">
#                     <button type="button" class="button button-filter med dropdown-toggle current-league-name"></button>
#                     <ul class="dropdown-menu league-nav med"></ul>
#                 </div>
#             </div>
#
#             <div class="scoreboard-dropdown-wrapper  conference-menu">
#                 <!-- mobile dropdown -->
#                 <div class="conference-nav-wrapper mobile-dropdown">
#                     <span class="mobile-arrow"></span>
#                     <select id="conference-nav"></select>
#                 </div>
#
#                 <!-- desktop dropdown -->
#                 <div class="dropdown-wrapper desktop-dropdown" data-behavior="button_dropdown">
#                     <button type="button" class="button button-filter med dropdown-toggle current-conference-name"></button>
#                     <ul class="dropdown-menu conference-nav med"></ul>
#                 </div>
#             </div>
#
#             <div class="scoreboard-dropdown-wrapper scores-date-pick">
#                 <div class="dropdown-wrapper" data-behavior="button_dropdown">
#                     <button type="button" class="button button-filter dropdown-toggle med selected-date"></button>
#                     <ul class="dropdown-menu date-nav med"></ul>
#                 </div>
#             </div>
#
#             <div class="scoreboard-dropdown-wrapper secondary-nav-container hidden"></div>
#
#             <div class="scores-prev controls inactive">&lt;</div>
#             <div id="fullbtn" class="view-full"></div>
#             <div class="scores-next controls">&gt;</div>
#             <div class="scores-carousel">
#                 <ul id="leagues"></ul>
#             </div>
#         </div>
#     </div>
# </section>
#
# <header id="global-header" class="espn-en user-account-management">
#     <div class="menu-overlay-secondary"></div>
#
# 	<div class="container">
# 		<a id="global-nav-mobile-trigger" href="#" data-route="false"><span>Menu</span></a><h1><a name="&lpos=sitenavdefault&lid=sitenav_main-logo" href='/' >ESPN</a></h1>
# 		<ul class="tools">
# 			<li class="search">
# <a href="#" class="icon-font-after icon-search-solid-after" id="global-search-trigger"></a>
# <div id="global-search" class="global-search">
# 	<input type="text" class="search-box" placeholder="Search Sports, Teams or Players..."><input type="submit" class="btn-search">
# </div></li>
#
# 			<li class="user" data-behavior="favorites_mgmt"></li>
#
# 			<li><a href="#" id="global-scoreboard-trigger" data-route="false">Scores</a></li>
# 		</ul>
#
#
# 	</div>
#
#
# <nav id="global-nav" data-loadtype="server">
# <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="/nfl/">NFL</a></li><li itemprop="name"><a itemprop="url" href="/nba/">NBA</a></li><li itemprop="name"><a itemprop="url" href="/mlb/">MLB</a></li><li itemprop="name"><a itemprop="url" href="/college-football/">NCAAF</a></li><li itemprop="name"><a itemprop="url" href="http://espnfc.com/">Soccer</a></li><li itemprop="name"><a itemprop="url" href="/nhl/">NHL</a></li><li itemprop="name"><a itemprop="url" href="#">&hellip;</a><div><ul class="split"><li itemprop="name"><a itemprop="url" href="/mens-college-basketball/">NCAAM</a></li><li itemprop="name"><a itemprop="url" href="/racing/nascar/">NASCAR</a></li><li itemprop="name"><a itemprop="url" href="/golf/">Golf</a></li><li itemprop="name"><a itemprop="url" href="/tennis/">Tennis</a></li><li itemprop="name"><a itemprop="url" href="/racing/">Racing</a></li><li itemprop="name"><a itemprop="url" href="/olympics/">Olympics</a></li><li itemprop="name"><a itemprop="url" href="http://espn.go.com/extra/specialolympics/">Special Olympics</a></li><li itemprop="name"><a itemprop="url" href="/college-sports/">NCAA</a></li><li itemprop="name"><a itemprop="url" href="/womens-basketball/">NCAAW</a></li><li itemprop="name"><a itemprop="url" href="/horse-racing/">Horse</a></li><li itemprop="name"><a itemprop="url" href="/mma/">MMA</a></li><li itemprop="name"><a itemprop="url" href="/boxing/">Boxing</a></li><li itemprop="name"><a itemprop="url" href="/womens-basketball/">WNBA</a></li><li itemprop="name"><a itemprop="url" href="http://espn.go.com/college-sports/football/recruiting/">RN FB</a></li><li itemprop="name"><a itemprop="url" href="http://espn.go.com/college-sports/basketball/recruiting/index">RN BB</a></li><li itemprop="name"><a itemprop="url" href="http://espncricinfo.com/">Cricket</a></li><li itemprop="name"><a itemprop="url" href="http://www.espnscrum.com/">Rugby</a></li><li itemprop="name"><a itemprop="url" href="http://xgames.com/">X Games</a></li><li itemprop="name"><a itemprop="url" href="/chalk/">Chalk</a></li><li itemprop="name"><a itemprop="url" href="/endurance/">Endurance</a></li><li itemprop="name"><a itemprop="url" href="http://www.tsn.ca/cfl">CFL</a></li><li itemprop="name"><a itemprop="url" href="http://espn.go.com/espys/2015/">ESPYS</a></li></ul></div></li><li class="pillar more-espn"><a href="#">More ESPN</a></li><li class="pillar fantasy"><a href="/fantasy/">Fantasy</a></li><li class="pillar listen"><a href="http://espn.go.com/espnradio/index">Listen</a></li><li class="pillar watch"><a href="http://espn.go.com/watchespn/index">Watch</a></li></ul>
#
# </nav>
#
#
#
#
# <nav id="global-nav-secondary" data-loadtype="server" >
# <div class="global-nav-container">
# <ul class="first-group"><li class="sports" itemprop="name"><span class="positioning"><a href="/nba/"><span class="brand-logo "><img src="http://a.espncdn.com/combiner/i?img=/i/teamlogos/leagues/500/nba.png&w=80&h=80&transparent=true"></span><span class="link-text">NBA</span></a></span></li><li class="sub"><a href="/nba/"  data-breakpoints="desktop,desktop-lg"  data-mobile="false" ><span class="link-text">Home</span><span class="link-text-short">Home</span></a></li><li class="sub"><a href="/nba/scoreboard" ><span class="link-text">Scores</span><span class="link-text-short">Scores</span></a></li><li class="sub"><a href="http://espn.go.com/nba/teams"  data-sportAbbrev="nba" ><span class="link-text">Teams</span><span class="link-text-short">Teams</span></a></li><li class="sub"><a href="/nba/schedule" ><span class="link-text">Schedule</span><span class="link-text-short">Schedule</span></a></li><li class="sub"><a href="http://espn.go.com/nba/statistics"  data-mobile="false" ><span class="link-text">Stats</span><span class="link-text-short">Stats</span></a></li><li class="sub"><a href="/nba/standings" ><span class="link-text">Standings</span><span class="link-text-short">Standings</span></a></li><li class="sub"><a href="http://espn.go.com/nba/players"  data-mobile="false" ><span class="link-text">Players</span><span class="link-text-short">Players</span></a></li><li class="sub"><a href="http://espn.go.com/nba/draft"  data-mobile="false" ><span class="link-text">Draft</span><span class="link-text-short">Draft</span></a></li><li class='sub sub-more-nolink sub-more-more has-sub'><a href='#'>More</a><div><ul class="split"><li class="sub"><a href="/blog/truehoop" ><span class="link-text">TrueHoop</span><span class="link-text-short">TrueHoop</span></a></li><li class="sub"><a href="/blog/nba/rumors/insider/" ><span class="link-text">Rumors</span><span class="link-text-short">Rumors</span></a></li><li class="sub"><a href="/blog/marc-stein" ><span class="link-text">Stein Line Live</span><span class="link-text-short">Stein Line Live</span></a></li><li class="sub"><a href="http://espn.go.com/nba/transactions"  data-mobile="false" ><span class="link-text">Transactions</span><span class="link-text-short">Transactions</span></a></li><li class="sub"><a href="http://espn.go.com/nba/salaries"  data-mobile="false" ><span class="link-text">Salaries</span><span class="link-text-short">Salaries</span></a></li><li class="sub"><a href="/chalk/" ><span class="link-text">Odds & Info</span><span class="link-text-short">Odds & Info</span></a></li><li class="sub"><a href="http://espn.go.com/nba/story/_/id/12307054/nba-free-agents-2016-2017" ><span class="link-text">Free Agents</span><span class="link-text-short">Free Agents</span></a></li><li class="sub"><a href="http://espn.go.com/nba/coaches"  data-mobile="false" ><span class="link-text">Coaches</span><span class="link-text-short">Coaches</span></a></li><li class="sub"><a href="http://espn.go.com/nba/history/awards"  data-mobile="false" ><span class="link-text">Awards</span><span class="link-text-short">Awards</span></a></li><li class="sub"><a href="http://espn.go.com/nba/history/leaders"  data-mobile="false" ><span class="link-text">All-Time Leaders</span><span class="link-text-short">All-Time Leaders</span></a></li><li class="sub insider"><a href="http://insider.espn.go.com/insider/pickcenter/index?sport=nba"  data-mobile="false" ><span class="link-text">PickCenter</span><span class="link-text-short">PickCenter</span></a></li><li class="sub"><a href="http://espn.go.com/nba/lines"  data-mobile="false" ><span class="link-text">Daily Lines</span><span class="link-text-short">Daily Lines</span></a></li><li class="sub"><a href="http://espn.go.com/nba/powerrankings"  data-mobile="false" ><span class="link-text">Power Rankings</span><span class="link-text-short">Power Rankings</span></a></li><li class="sub"><a href="http://espn.go.com/nba/powerrankings" ><span class="link-text">Power Rankings</span><span class="li ...
# 	<script type="text/javascript">
# 		var espn = espn || {};
# 		espn.nav = espn.nav || {};
# 		espn.nav.navId = 11929946;
# 		espn.nav.isFallback = false;
#
#
#
# 	</script>
# </div>
# </nav>
#
# </header>
#             </div>
#
#             <section id="pane-main">
#
#             	<div id="custom-nav" data-id="standings"></div>
#
#             	<div class="ad-slot ad-slot-banner ad-wrapper" data-slot-type="banner" data-slot-kvps="pos=banner"></div>
#
#                 <section id="main-container" class="page-container">
#
#                     <div class="main-content layout-full">
#                         <section class="col-a"><header class="sub-header-module"><h1>NBA Standings - 2015-16</h1><div class="separator"><div class="dropdown-wrapper hoverable" data-behavior="button_dropdown"><button class="button-filter med dropdown-toggle">Resources</button><ul class="dropdown-menu drop-left med" role="menu"><li><a  name="&lpos=nba:standings:quicklinks:nba+playoff+matchups" itemprop="url" href="http://espn.go.com/nba/playoffs/matchups" target="_top" class="">NBA Playoff Matchups</a></li><li><a  name="&lpos=nba:standings:quicklinks:basketball+power+index" itemprop="url" href="http://espn.go.com/nba/story/_/page/Basketball-Power-Index/espn-nba-basketball-power-index" target="_top" class="">Basketball Power Index</a></li><li><a  name="&lpos=nba:standings:quicklinks:playoff+odds" itemprop="url" href="http://espn.go.com/nba/story/_/page/BPI-Playoff-Odds/espn-nba-basketball-power-index-playoff-odds" target="_top" class="">Playoff Odds</a></li><li><a  name="&lpos=nba:standings:quicklinks:real+plus-minus" itemprop="url" href="http://espn.go.com/nba/statistics/rpm/_/sort/RPM" target="_top" class="">Real Plus-Minus</a></li><li><a  name="&lpos=nba:standings:quicklinks:steins+power+rankings" itemprop="url" href="http://espn.go.com/nba/powerrankings" target="_top" class="">Stein's Power Rankings</a></li><li><a  name="&lpos=nba:standings:quicklinks:nba+predictions" itemprop="url" href="http://projects.fivethirtyeight.com/2016-nba-picks/" target="_top" class="external">NBA Predictions</a></li></ul></div></div></header><div class="tab-wrap internal-wrap desktop"><ul class="tabs desktop-tablet-only" data-behavior="tabs_transform" role="tablist"><li class="active"><a  name="&lpos=nba:standings:filter:standings" href="/nba/standings"><span>Standings</span></a></li><li><a  name="&lpos=nba:standings:filter:expanded" href="/nba/standings/_/view/expanded"><span>Expanded Standings</span></a></li><li><a  name="&lpos=nba:standings:filter:vs-division" href="/nba/standings/_/view/vs-division"><span>Vs. Division Standings</span></a></li></ul><div class="dropdown-wrapper mobile-only" data-behavior="button_dropdown"><button type="button" class="button-filter med dropdown-toggle">Standings</button><ul class="dropdown-menu med" role="menu"><li class="active"><a href="/nba/standings"><span>Standings</span></a></li><li><a href="/nba/standings/_/view/expanded"><span>Expanded Standings</span></a></li><li><a href="/nba/standings/_/view/vs-division"><span>Vs. Division Standings</span></a></li></ul></div></div><div class="tab-content"><div class="tab-pane active"><form class="filters desktop"><fieldset><div class="form-group button-group"><a  name="&lpos=nba:standings:filter:league" href="/nba/standings/_/group/league" class="button-filter-alt med first">League</a><a  name="&lpos=nba:standings:filter:conference" href="/nba/standings" class="button-filter-alt med active">Conference</a><a  name="&lpos=nba:standings:filter:division" href="/nba/standings/_/group/division" class="button-filter-alt med last">Division</a><div class="wrapper mobile-only"><div class="filter"><a href="#" class="filter-modal button-filter med icon-font-before icon-filter-solid-before" data-behavior="filter_modal"></a></div></div></div><div class="form-group mobile"><div class="wrapper"><div class="dropdown-wrapper hoverable width-auto" data-behavior="button_dropdown"><button type="button" class="button-filter med dropdown-toggle">2015-16</button><ul class="dropdown-menu med" role="menu"><li><a  name="&lpos=nba:standings:filter:year" href="/nba/standings">2015-16</a></li><li><a  name="&lpos=nba:standings:filter:year" href="/nba/standings/_/season/2015">2014-15</a></li><li><a  name="&lpos=nba:standings:filter:year" href="/nba/standings/_/season/2014">2013-14</a></li><li><a  name="&lpos=nba:standings:filter:year" href="/nba/standings/_/season/2013">2012-13</a></li><li><a  name="&lpos=nba:standings:filter:year" href="/nba/standings/_/season/2012">2011-12</a></li><li><a  name="&lp ...
# 		<script type="text/javascript">
# 			var espn = espn || {};
# 			espn.standings = {
# 				baseUrl: "/nba/standings",
# 				resetUrl: "/nba/standings",
# 				header: "NBA Standings - 2015-16",
# 				year: 2016,
# 				maxYear: 2016,
# 				minYear: 2002,
# 				seasonTypeName: "Regular Season",
# 				seasonTypeAbbrev: "reg",
# 				seasonTypes: {"2002":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2003":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2006":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2007":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2004":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2005":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2010":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2011":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2008":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2009":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2014":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2015":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2012":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2013":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}],"2016":[{"id":"2","name":"Regular Season","abbreviation":"reg"},{"id":"1","name":"Preseason","abbreviation":"pre"}]},
# 				splitSeason: true,
# 				shiftSeasonForward: false,
# 				showSeasonDropdown: true,
# 				currentView: "standings"
# 			};
# 		</script>
#
#                     </div>
#
#
#
#                 </section>
#
#
#             </section>
#         </div>
#
#
# <script>
# 	var espn_ui = window.espn_ui || {};
# 	espn_ui.staticRef = "http://a.espncdn.com/redesign/0.283.6";
# 	espn_ui.deviceType = "desktop";
# 	espn.api = {};
# 	espn.api.disasterURLs = {
# 		"cdn.espn.go.com":"cdn.espn.go.com",
# 		"sports.core.api.espn.com":"sports.core.api.espn.com",
# 		"site.api.espn.com":"site.api.espn.com",
# 		"site.api.prod.espninfra.starwave.com":"site.api.prod.espninfra.starwave.com",
# 		"fan.core.api.espn.go.com":"fan.core.api.espn.go.com",
# 		"site.core.api.prod.espninfra.starwave.com":"site.core.api.prod.espninfra.starwave.com",
# 		"api.espn.go.com":"api.espn.go.com",
# 		"api-app.espn.go.com":"api-app.espn.go.com",
# 		"api.prod.espninfra.starwave.com":"api.prod.espninfra.starwave.com"
# 	};
# 	espn_ui.webview = false;
# </script>
#
# <script src="http://a.espncdn.com/redesign/0.283.6/js/espn-critical.js"></script>
#
#
# <script type="text/javascript">
# 	var espn = espn || {};
# 	/* building skeleton for namespace */
#     espn.scoreboard = {
#         topics: {
#             scoreboard: "",
#             scoreboxes: []
#         },
#         models: {},
#         views: {},
#         collections: {},
#         timezoneOffset: 0,
#         favorites: {},
#         editData: {},
#         activeLeague: "nba",
#         hiddenLeague: "null",
#         settings: {
# 			activeLeagues: [{"sportId":0,"league":"topEvents","displayName":"Top Events"},{"sportId":28,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://espn.go.com/nfl/scoreboard"},"sport":"football","top25Only":true,"league":"nfl","displayName":"NFL"},{"sportId":41,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://espn.go.com/mens-college-basketball/scoreboard"},"sport":"basketball","top25Only":true,"league":"mens-college-basketball","displayName":"NCAAM"},{"sportId":46,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://espn.go.com/nba/scoreboard"},"sport":"basketball","top25Only":true,"league":"nba","displayName":"NBA"},{"sportId":90,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://scores.espn.go.com/nhl/scoreboard"},"sport":"hockey","top25Only":true,"league":"nhl","displayName":"NHL"},{"sportId":54,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://scores.espn.go.com/ncw/scoreboard"},"sport":"basketball","top25Only":true,"league":"womens-college-basketball","displayName":"NCAAW"},{"sportId":1106,"link":{"title":"Full Leaderboard &#187;","onclick":"","href":"http://scores.espn.go.com/golf/leaderboard"},"sport":"golf","top25Only":true,"league":"pga","displayName":"Golf (M)"},{"sportId":23,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://espn.go.com/college-football/scoreboard"},"sport":"football","top25Only":false,"league":"college-football","displayName":"NCAAF"},{"sportId":3918,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://www.espnfc.com/scores?cc=5901"},"sport":"soccer","top25Only":true,"league":"eng.fa","displayName":"English FA Cup"},{"sportId":700,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://www.espnfc.com/scores?cc=5901"},"sport":"soccer","top25Only":true,"league":"eng.1","displayName":"Premier League"},{"sportId":740,"link":{"title":"Full Scoreboard &#187;","onclick":"","href":"http://www.espnfc.com/scores?cc=5901"},"sport":"soccer","top25Only":true,"league":"esp.1","displayName":"La Liga"}],
# 			useStatic: false,
# 			initialTopic: "event-basketball-nba",
# 			version: 2
#
#
#
#
#
#
# 		},
# 		data: {"sports":[{"uid":"s:40","id":"40","leagues":[{"uid":"s:40~l:46","id":"46","events":[{"uid":"s:40~l:46~e:400828437~c:400828437","summary":"2:23 - 2nd","location":"STAPLES Center","seasonType":2,"clock":"2:23","status":"in","seriesSummary":"LAC leads 1-0","competitors":[{"uid":"s:40~l:46~t:12","logo":"http://a.espncdn.com/i/teamlogos/nba/500/scoreboard/lac.png","competitionIdPrevious":"400828422","score":"41","links":[{"text":"Sportscenter","rel":["sportscenter","app"],"href":"sportscenter://x-callback-url/showClubhouse?uid=s:40~l:46~t:12&section=scores"}],"winner":false,"competitionIdNext":"400828445","type":"team","abbreviation":"LAC","id":"12","record":"23-13","name":"Clippers","group":"4","logoDark":"http://a.espncdn.com/i/teamlogos/nba/500-dark/scoreboard/lac.png","homeAway":"home"},{"uid":"s:40~l:46~t:30","logo":"http://a.espncdn.com/i/teamlogos/nba/500/scoreboard/cha.png","competitionIdPrevious":"400828420","score":"43","links":[{"text":"Sportscenter","rel":["sportscenter","app"],"href":"sportscenter://x-callback-url/showClubhouse?uid=s:40~l:46~t:30&section=scores"}],"winner":false,"competitionIdNext":"400828450","type":"team","abbreviation":"CHA","id":"30","record":"17-18","name":"Hornets","group":"9","logoDark":"http://a.espncdn.com/i/teamlogos/nba/500-dark/scoreboard/cha.png","homeAway":"away"}],"broadcast":"","link":"http://espn.go.com/nba/gamecast?gameId=400828437","links":[{"text":"Gamecast","href":"http://espn.go.com/nba/gamecast?gameId=400828437"},{"text":"Box Score","href":"http://espn.go.com/nba/boxscore?gameId=400828437"}],"date":"2016-01-09T20:30:00Z","period":2,"onWatch":false,"id":"400828437","timeValid":true,"season":2016,"name":null,"broadcasts":[{"region":"us","isNational":false,"priority":0,"name":"FSN Prime Ticket","broadcasterId":243,"callLetters":"FSW2","broadcastId":243,"shortName":"FSW2","type":"TV","lang":"en","typeId":1}]},{"uid":"s:40~l:46~e:400828438~c:400828438","summary":"2016-01-09T22:00:00Z","location":"Philips Arena","seasonType":2,"clock":"0:00","status":"pre","seriesSummary":"Series starts 1/9","competitors":[{"uid":"s:40~l:46~t:1","logo":"http://a.espncdn.com/i/teamlogos/nba/500/scoreboard/atl.png","competitionIdPrevious":"400828423","score":"0","links":[{"text":"Sportscenter","rel":["sportscenter","app"],"href":"sportscenter://x-callback-url/showClubhouse?uid=s:40~l:46~t:1&section=scores"}],"winner":false,"competitionIdNext":"400828464","type":"team","abbreviation":"ATL","id":"1","record":"22-15","name":"Hawks","group":"9","logoDark":"http://a.espncdn.com/i/teamlogos/nba/500-dark/scoreboard/atl.png","homeAway":"home"},{"uid":"s:40~l:46~t:4","logo":"http://a.espncdn.com/i/teamlogos/nba/500/scoreboard/chi.png","competitionIdPrevious":"400828424","score":"0","links":[{"text":"Sportscenter","rel":["sportscenter","app"],"href":"sportscenter://x-callback-url/showClubhouse?uid=s:40~l:46~t:4&section=scores"}],"winner":false,"competitionIdNext":"400828454","type":"team","abbreviation":"CHI","id":"4","record":"22-12","name":"Bulls","group":"2","logoDark":"http://a.espncdn.com/i/teamlogos/nba/500-dark/scoreboard/chi.png","homeAway":"away"}],"broadcast":"","link":"http://espn.go.com/nba/preview?gameId=400828438","links":[{"text":"Preview","href":"http://espn.go.com/nba/preview?gameId=400828438"},{"text":"Tickets","href":"http://www.stubhub.com/atlanta-hawks-tickets-atlanta-hawks-atlanta-philips-arena-1-9-2016/event/9371111/"}],"date":"2016-01-09T22:00:00Z","period":0,"onWatch":false,"id":"400828438","timeValid":true,"season":2016,"name":null,"broadcasts":[{"region":"us","isNational":false,"priority":0,"name":"WGN-TV, Chicago","broadcasterId":561,"callLetters":"WGN","broadcastId":561,"shortName":"WGN","type":"TV","lang":"en","typeId":1}]},{"uid":"s:40~l:46~e:400828439~c:400828439","summary":"2016-01-10T00:00:00Z","location":"Amway Center","seasonType":2,"clock":"0:00","status":"pre","seriesSummary":"WSH leads 3-0","competitors":[{"uid":"s:40~l:46~t:19","logo":"http://a.espncdn.com/i/teamlog ...
#     };
# </script>
#
#
# 	<script type="text/javascript">jQuery.subscribe("espn.defer.end", function(){ espn.scoreboard.init(); })</script>
#
# 	<script>
# 	(function(){
# 		var deferLoaded = false;
# 		function loadDefer(){
# 			if( !deferLoaded ){
# 				var deferScripts = ['http://a.espncdn.com/redesign/0.283.6/js/espn-defer.js', 'http://a.espncdn.com/redesign/0.283.6/js/espn-defer-low.js'];
# 				for( var s = 0; s < deferScripts.length; s++ ){
# 				  	var script = document.createElement('script');
# 				    script.src = deferScripts[s];
# 				    document.getElementsByTagName('head')[0].appendChild(script);
# 				}
# 			    deferLoaded = true;
# 			}
# 		}
# 		if( window.espn.loadType === "loadEnd" && ( espn_ui.device.isMobile === true || espn_ui.device.isTablet === true ) ){
# 			$( window ).load(function() {
# 				setTimeout( loadDefer, 0 )
# 			});
# 			setTimeout( loadDefer, 5000 )
# 		}else{
# 			loadDefer();
# 		}
#
# 	})();
# 	</script>
#
#
#
# <script>espn_ui.Helpers.translate.init();</script>
# <script type="text/javascript" src="http://a.espncdn.com/redesign/0.283.6/js/modules/standings/filter.js"></script>
#
#
# 	<!--BEGIN QUALTRICS SITE INTERCEPT-->
# 	<div id='SI_9EvK9r52GPmgW9v'><!--DO NOT REMOVE-CONTENTS PLACED HERE--></div>
# 	<!--END SITE INTERCEPT-->
#
#
# 	<!-- SiteCatalyst code version: AppMeasurement 1.0 Copyright 1996-2013 Adobe, Inc. -->
# 	<script type="text/javascript">
#
# 	if (typeof s_omni === 'undefined') {
# 		jQuery(function($){
# 			$.getScriptCache("http://a.espncdn.com/redesign/0.283.6/js/espn-analytics.js", function() {	var deferEvent = "user.parsed",	trackInit = false;
# 	function initTrack(){		if (!trackInit && espn.track && (typeof espn.track.init) === 'function') {			espn.track.init({"chartbeat":{"authors":"standings:regular","title":"NBA Regular Season Conference Standings - National Basketball Association","sections":"nba","loadVidJS":true,"loadPubJS":false,"path":"/nba/standings","domain":"espn.go.com","zone":"espn.go.com.us.nba"},"device":"desktop","omniture":{"site":"espn","pageName":"nba:standings","premium":"premium-no","sport":"basketball","hier1":"nba:standings","contentType":"standings:regular","league":"nba","convrSport":"basketball","lang":"en_us","pageURL":"espn.go.com/nba/standings","section":"nba","navMethod":"sitenav","countryRegion":"en-us","espn3ContentType":"standings:regular:espn:nba","sections":"nba:standings","account":"wdgespcom"},"isFeaturePhone":false,"ABTest":{"raw":"{\"target\":{\"enabled\":false,\"placements\":[{\"site\":\"espn.co.uk\",\"flag\":false,\"regexp\":\"(/)\"},{\"site\":\"espn.go.com\",\"flag\":true,\"regexp\":\"(/.*)\"},{\"site\":\"espn-qa.go.com\",\"flag\":true,\"regexp\":\"(/.*)\"}],\"script\":\"http://a.espncdn.com/prod/scripts/analytics/target.20.r2.js\"},\"optimizely\":{\"enabled\":true,\"placements\":[{\"site\":\"espn.co.uk\",\"flag\":false,\"regexp\":\"(/)\"},{\"site\":\"espn.go.com\",\"flag\":true,\"regexp\":\"(/.*)\"}],\"oldscript\":\"http://sports-ak.espn.go.com/sports/optimizely.js?local\",\"script\":\"http://cdn.optimizely.com/js/310987714.js\"},\"fastcast\":{\"enabled\":true,\"placements\":{\"/nfl/index\":\"true\",\"/nba/index\":\"true\",\"/mlb/index\":\"true\",\"^/.+$\":\"false\"},\"script\":\"http://a.espncdn.com/combiner/c?js=analytics/espn.fastcastTracking.4.js\"}}","optimizelyURLs":[{"site":"espn.co.uk","flag":false,"regexp":"(/)"},{"site":"espn.go.com","flag":true,"regexp":"(/.*)"}],"tScript":"http://a.espncdn.com/prod/scripts/analytics/target.20.r2.js","host":"espn.go.com","environment":"local","optimizely":true,"target":false,"domain":"espn.go.com","isTargeted":true,"isOptimizied":true,"targetURLs":[{"site":"espn.co.uk","flag":false,"regexp":"(/)"},{"site":"espn.go.com","flag":true,"regexp":"(/.*)"},{"site":"espn-qa.go.com","flag":true,"regexp":"(/.*)"}],"oScript":"http://cdn.optimizely.com/js/310987714.js"}});			trackInit = true;		}	}	$.subscribe(deferEvent, initTrack);	setTimeout(initTrack, 5000);	if(window.espn_ui.userParsed){		$.publish('user.parsed');	}}
# );
# 		});
# 	}
#
# 	</script>
#
# 	<!-- End SiteCatalyst code version: AppMeasurement 1.0 --><script>
# var sbDebug = window.espn && window.espn.flow && window.espn.flow.debug === true;
# if(!sbDebug) {
# 	if (espn_ui.device.isMobile === true || espn_ui.device.isTablet === true) {
# 		jQuery.subscribe("espn.defer.end", function() {
# 			if (DTSS_WebSockets) {
# 				DTSS_WebSockets.PRECONNECT = true;
# 				DTSS_WebSockets.FORCE_PRECONNECT = true;
# 			}
# 		})
# 	} else {
# 		if (DTSS_WebSockets) {
# 			DTSS_WebSockets.PRECONNECT = true;
# 			DTSS_WebSockets.FORCE_PRECONNECT = true;
# 		}
# 	}
# }
# </script>
# 	</body>
# </html>

# %%
soup = BeautifulSoup(z.content, from_encoding='UTF-8')
t = soup.findAll('table')
# Out:
# C:\Users\Benjamin\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
t[1]
# Out:
# <table cellpadding="0" cellspacing="0" class="standings has-team-logos" data-behavior="responsive_table" data-fix-cols="1" data-mobile-force-responsive="true" data-set-cell-heights="false" data-text-contract="Contract table" data-text-expand="Expand table"><caption><span class="long-caption">Western Conference</span></caption><colgroup><col></col></colgroup><colgroup><col></col><col></col><col></col><col></col></colgroup><colgroup><col></col><col></col><col></col><col></col></colgroup><colgroup><col></col><col></col><col></col></colgroup><colgroup><col></col><col></col></colgroup><thead class="standings-categories"><th style="text-align: left"><span></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Wins"><a href="/nba/standings/_/sort/wins" name="&amp;lpos=nba:standings:sort:wins">W</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Losses"><a href="/nba/standings/_/sort/losses" name="&amp;lpos=nba:standings:sort:losses">L</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Winning Percentage"><a href="/nba/standings/_/sort/winpercent" name="&amp;lpos=nba:standings:sort:winning+percentage">PCT</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Games Back"><a href="/nba/standings/_/sort/gamesbehind" name="&amp;lpos=nba:standings:sort:games+back">GB</a></span></th><th><span class="tooltip" data-tooltip="Home Record">HOME</span></th><th><span class="tooltip" data-tooltip="Road Record">ROAD</span></th><th><span class="tooltip" data-tooltip="Division Record">DIV</span></th><th><span class="tooltip" data-tooltip="Conference Record">CONF</span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Points Per Game"><a href="/nba/standings/_/sort/avgpointsfor" name="&amp;lpos=nba:standings:sort:points+per+game">PPG</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Opponent Points Per Game"><a href="/nba/standings/_/sort/avgpointsagainst" name="&amp;lpos=nba:standings:sort:opponent+points+per+game">OPP PPG</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Average Point Differential"><a href="/nba/standings/_/sort/differential" name="&amp;lpos=nba:standings:sort:average+point+differential">DIFF</a></span></th><th data-sortable="true"><span class="tooltip" data-tooltip="Current Streak"><a href="/nba/standings/_/sort/streak" name="&amp;lpos=nba:standings:sort:current+streak">STRK</a></span></th><th><span class="tooltip" data-tooltip="Record last 10 games">L10</span></th></thead><tr class=" standings-row"><td class="team " style="text-align:left;white-space:nowrap;"><span class="number">1</span><a href="/nba/team/_/name/gs" name="&amp;lpos=nba:standings:team"><span class="teams sprite-nba-teams-25 sprite-25-team-9"></span></a><a href="/nba/team/_/name/gs" name="&amp;lpos=nba:standings:team"><span><span class="team-names">Golden State Warriors</span><abbr title="Golden State Warriors">GS</abbr></span></a></td><td class="" style="white-space:no-wrap;">34</td><td class="" style="white-space:no-wrap;">2</td><td class="" style="white-space:no-wrap;">.944</td><td class="" style="white-space:no-wrap;">-</td><td class="center" style="white-space:no-wrap;">17-0</td><td class="center" style="white-space:no-wrap;">17-2</td><td class="center" style="white-space:no-wrap;">9-0</td><td class="center" style="white-space:no-wrap;">22-1</td><td class="" style="white-space:no-wrap;">114.1</td><td class="" style="white-space:no-wrap;">101.9</td><td class=" positive" style="white-space:no-wrap;">+12.2</td><td class="" style="white-space:no-wrap;">W5</td><td class="" style="white-space:no-wrap;">9-1</td></tr><tr class=" standings-row"><td class="team " style="text-align:left;white-space:nowrap;"><span class="number">2</span><a href="/nba/team/_/name/sa" name="&amp;lpos=nba:standings:team"><span class="teams sprite-nba-teams-25 sprite-25-team-24"></span></a><a href="/nba/team/_/name/sa" name="&amp;lpos=nba ...

# %%
df = pd.read_html(t[1])[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-b3f343a1fea5> in <module>()
# ----> 1 df = pd.read_html(t[1])[0]
#
# C:\Users\Benjamin\Anaconda2\lib\site-packages\pandas\io\html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     864     _validate_header_arg(header)
#     865     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 866                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# C:\Users\Benjamin\Anaconda2\lib\site-packages\pandas\io\html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     716     retained = None
#     717     for flav in flavor:
# --> 718         parser = _parser_dispatch(flav)
#     719         p = parser(io, compiled_match, attrs, encoding)
#     720
#
# C:\Users\Benjamin\Anaconda2\lib\site-packages\pandas\io\html.pyc in _parser_dispatch(flavor)
#     661     if flavor in ('bs4', 'html5lib'):
#     662         if not _HAS_HTML5LIB:
# --> 663             raise ImportError("html5lib not found, please install it")
#     664         if not _HAS_BS4:
#     665             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it
